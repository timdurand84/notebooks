# %%
# Data Wrangling
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 999)

# Data Import
from scipy.io.arff import loadarff 

# Helper Functions
import AnalyseHelpers as a
import CleanseHelpers as c

# Visualisation
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [8.0, 5.0]
import seaborn as sns
sns.set(font_scale=1)
# Set the styling for dataframes
dfstyles = [dict(selector="caption", props=[("font-size", "120%"),("color", "black"),("text-align", "center")])]
from IPython.display import display,HTML

# Model Pre-processing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV

#Model Metrics
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, classification_report, roc_curve, plot_confusion_matrix

#Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
#from sklearn.naive_bayes import CategoricalNB

# Model Params
classweight = {0:1,1:5} #"balanced" {0:0.2,1:0.8} {0:1,1:5}
randomstate = 4325
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-51-9333cc4498de> in <module>
#      25
#      26 #Model Metrics
# ---> 27 from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, classification_report, roc_curve, plot_confusion_matrix
#      28
#      29 #Models
#
# ImportError: cannot import name 'plot_confusion_matrix' from 'sklearn.metrics' (C:\Users\durandt\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\__init__.py)

# %%
import sklearn
sklearn.__version__
# Out:
# '0.21.3'

# %% [markdown]
# HTML('''<script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <b>NOTE</b>: AnalyseHelpers and CleanseHelpers are supplementary modules, and should reside in the same directory as this notebook
# <br>
# The code for this notebook is, by default, hidden. To display the code cells, click <a href="javascript:code_toggle()">here</a>.\r\n''')

# %% [markdown]
# ### Consolidation

# %%
# Import training data to df from arff file
trainingdata = 'C:/Users/durandt/Documents/Aston/3 - Data Mining/Assessment/CWdata/CWdata_train.arff'
testdata = 'C:/Users/durandt/Documents/Aston/3 - Data Mining/Assessment/CWdata/CWdata_test.arff'
raw_training_data = loadarff(trainingdata)
traindf = pd.DataFrame(raw_training_data[0])

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Preliminary cleansing

# %%
# Profile the data using helper function
display(a.dataprofile(traindf).style.set_table_styles(dfstyles).set_caption('Data profile: Training data'))
# Out:
# <style  type="text/css" >
#     #T_74055036_18d9_11ea_9b75_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_74055036_18d9_11ea_9b75_005056974139" ><caption>Data profile: Training data</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column</th>        <th class="col_heading level0 col1" >Max Length Value</th>        <th class="col_heading level0 col2" >Max Length</th>        <th class="col_heading level0 col3" >Min Length Value</th>        <th class="col_heading level0 col4" >Min Length</th>        <th class="col_heading level0 col5" >Null #</th>        <th class="col_heading level0 col6" >Null %</th>        <th class="col_heading level0 col7" >Data Type</th>        <th class="col_heading level0 col8" >Unique Values</th>        <th class="col_heading level0 col9" >Row Count</th>        <th class="col_heading level0 col10" >Mean</th>        <th class="col_heading level0 col11" >Max</th>        <th class="col_heading level0 col12" >Min</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_74055036_18d9_11ea_9b75_005056974139level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col0" class="data row0 col0" >LIMIT_BAL</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col1" class="data row0 col1" >1e+06</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col2" class="data row0 col2" >9</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col3" class="data row0 col3" >50000</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col4" class="data row0 col4" >7</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col7" class="data row0 col7" >float64</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col8" class="data row0 col8" >80</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col9" class="data row0 col9" >25000</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col10" class="data row0 col10" >167589</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col11" class="data row0 col11" >1e+06</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row0_col12" class="data row0 col12" >10000</td>
#             </tr>
#             <tr>
#                         <th id="T_74055036_18d9_11ea_9b75_005056974139level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col0" class="data row1 col0" >SEX</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col1" class="data row1 col1" >b'M'</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col2" class="data row1 col2" >4</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col3" class="data row1 col3" >b'M'</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col4" class="data row1 col4" >4</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col7" class="data row1 col7" >string</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col8" class="data row1 col8" >2</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col9" class="data row1 col9" >25000</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col10" class="data row1 col10" >N/A</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col11" class="data row1 col11" >N/A</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row1_col12" class="data row1 col12" >N/A</td>
#             </tr>
#             <tr>
#                         <th id="T_74055036_18d9_11ea_9b75_005056974139level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col0" class="data row2 col0" >EDUCATION</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col1" class="data row2 col1" >b'2'</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col2" class="data row2 col2" >4</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col3" class="data row2 col3" >b'2'</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col4" class="data row2 col4" >4</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col6" class="data row2 col6" >0</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col7" class="data row2 col7" >string</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col8" class="data row2 col8" >7</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col9" class="data row2 col9" >25000</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col10" class="data row2 col10" >N/A</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col11" class="data row2 col11" >N/A</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row2_col12" class="data row2 col12" >N/A</td>
#             </tr>
#             <tr>
#                         <th id="T_74055036_18d9_11ea_9b75_005056974139level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col0" class="data row3 col0" >MARRIAGE</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col1" class="data row3 col1" >b'Divorced'</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col2" class="data row3 col2" >11</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col3" class="data row3 col3" >b'Single'</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col4" class="data row3 col4" >9</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col6" class="data row3 col6" >0</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col7" class="data row3 col7" >string</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col8" class="data row3 col8" >4</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col9" class="data row3 col9" >25000</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col10" class="data row3 col10" >N/A</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col11" class="data row3 col11" >N/A</td>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row3_col12" class="data row3 col12" >N/A</td>
#             </tr>
#             <tr>
#                         <th id="T_74055036_18d9_11ea_9b75_005056974139level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_74055036_18d9_11ea_9b75_005056974139row4_col0" class="data row4 col0" >AGE</td>

# %% [markdown]
# One can see from the above table that there are 24 columns and 25000 observations, none of the features have missing values, and there are two data types: object and float.
# The object columns are encoded and therefore required decoding using a UTF-8 decoder.

# %%
# Decode character string columns 
objectcols = ['SEX', 'EDUCATION', 'MARRIAGE','DEFAULT']
for i in objectcols:
    traindf[i] = traindf[i].str.decode(encoding = 'UTF-8')
#traindf[['SEX', 'EDUCATION', 'MARRIAGE','DEFAULT']].head(3)
display(traindf[['SEX', 'EDUCATION', 'MARRIAGE','DEFAULT']].head(3).style.set_table_styles(dfstyles).set_caption('Cleansed String Columns'))
# Out:
# <style  type="text/css" >
#     #T_741a9568_18d9_11ea_bed1_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_741a9568_18d9_11ea_bed1_005056974139" ><caption>Cleansed String Columns</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SEX</th>        <th class="col_heading level0 col1" >EDUCATION</th>        <th class="col_heading level0 col2" >MARRIAGE</th>        <th class="col_heading level0 col3" >DEFAULT</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_741a9568_18d9_11ea_bed1_005056974139level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row0_col0" class="data row0 col0" >M</td>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row0_col1" class="data row0 col1" >2</td>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row0_col2" class="data row0 col2" >Married</td>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row0_col3" class="data row0 col3" >Yes</td>
#             </tr>
#             <tr>
#                         <th id="T_741a9568_18d9_11ea_bed1_005056974139level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row1_col0" class="data row1 col0" >F</td>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row1_col2" class="data row1 col2" >Married</td>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row1_col3" class="data row1 col3" >No</td>
#             </tr>
#             <tr>
#                         <th id="T_741a9568_18d9_11ea_bed1_005056974139level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row2_col0" class="data row2 col0" >F</td>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row2_col1" class="data row2 col1" >2</td>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row2_col2" class="data row2 col2" >Married</td>
#                         <td id="T_741a9568_18d9_11ea_bed1_005056974139row2_col3" class="data row2 col3" >No</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Based on the data description, the EDUCATION variable requires some cleansing.
# The numerical values were converted to a description of the education level to provide better interpretability later.
# As 4=others, 5=unknown, 6=unknown; these attribute values were grouped together as Others. There is also a category of 0 present in the data that was not present in the description, this was also set to Others.

# %%
print("Initial unique values in EDUCATION: ",traindf['EDUCATION'].unique())
# Out:
# Initial unique values in EDUCATION:  ['2' '3' '1' '0' '5' '4' '6']

# %%
# Cleanse Eductation column with replace
traindf['EDUCATION'] = traindf['EDUCATION'].replace('0','Others').replace('1','Graduate_School').replace('2','University')\
    .replace('3','High_School').replace('4','Others').replace('5','Others').replace('6','Others')

# %%
# Check results
print("Post cleanse unique values in EDUCATION: ",traindf['EDUCATION'].unique())
# Out:
# Post cleanse unique values in EDUCATION:  ['University' 'High_School' 'Graduate_School' 'Others']

# %% [markdown]
# Anything below 0 in the PAY_n columns is equivalent to 0; therefore any value less than 0 was set to 0.

# %%
# Create list of parameter groups
paylist = ['PAY_0', 'PAY_2','PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# Cleanse paylist
for p in paylist:
    traindf[p] = traindf[p].apply(c.cleanseltzero)

# %% [markdown]
# ### Exploration

# %% [markdown]
# #### Class Imbalance

# %%
ax = sns.countplot(x="DEFAULT", data=traindf).set_title('Default Frequency', size = 14)
plt.show()
traindf['DEFAULT_NUM'] = traindf['DEFAULT'].replace('Yes',1).replace('No',0)
print("Percentage of Defaults: ",sum(traindf['DEFAULT_NUM']) / len(traindf['DEFAULT_NUM']) * 100,'%')
# Out:
# Percentage of Defaults:  22.06 %

# %% [markdown]
# #### Demographic Analysis

# %%
plt.rcParams['figure.figsize'] = [14.0, 5.0]
ax = sns.boxplot(y='AGE', x="MARRIAGE",hue="SEX" ,data=traindf, palette="Set2", showfliers=False).set_title("Box Plot: Marriage, Age and Sex", size=14)
plt.show()

ax = sns.boxplot(y='AGE', x="MARRIAGE",hue="EDUCATION" ,data=traindf, palette="Set2",showfliers=False).set_title("Box Plot: Marriage, Age and Education", size=14)
plt.show()

ax = sns.boxplot(y='LIMIT_BAL', x="MARRIAGE",hue="EDUCATION" ,data=traindf, palette="Set2",showfliers=False).set_title("Box Plot: Marriage, Education and Balance Limit", size=14)
plt.show()

fig, axes = plt.subplots(1, 3, sharey=True)
axes = axes.flatten()
fig.suptitle('Stacked bar charts: Education and Marriage with relation to Default', size =14)

stable=pd.crosstab(traindf.SEX,traindf.DEFAULT)
stable.div(stable.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax = axes[0], legend=False)
plt.xlabel('SEX')
axes[0].set_xticklabels(axes[0].get_xticklabels(),rotation=0, horizontalalignment='right')

etable=pd.crosstab(traindf.EDUCATION,traindf.DEFAULT)
etable.div(etable.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax = axes[1], legend=False)
plt.xlabel('EDUCATION')
axes[1].set_xticklabels(axes[1].get_xticklabels(),rotation=45, horizontalalignment='right')

mtable=pd.crosstab(traindf.MARRIAGE,traindf.DEFAULT)
mtable.div(mtable.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, ax = axes[2], legend=False)
plt.xlabel('MARRIAGE')
axes[2].set_xticklabels(axes[2].get_xticklabels(),rotation=45, horizontalalignment='right')
fig.legend(stable,loc = 5)
fig.text(0.08, 0.5, 'Default', va='center', rotation='vertical', size=14)
plt.show()

# %% [markdown]
# Sex and Marriage are nominal variables and Education is ordinal.
# One can see from the above, that Sex does not appear to be a good predictor of whether a person will default, but Education, and Marriage do seem to have some importance.

# %% [markdown]
# #### Correlation

# %%
display(traindf.groupby('DEFAULT').mean().style.set_table_styles(dfstyles).\
        set_caption('Mean of numerical variables in relation to default'))
# Out:
# <style  type="text/css" >
#     #T_7594a834_18d9_11ea_8c96_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_7594a834_18d9_11ea_8c96_005056974139" ><caption>Mean of numerical variables in relation to default</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >LIMIT_BAL</th>        <th class="col_heading level0 col1" >AGE</th>        <th class="col_heading level0 col2" >PAY_0</th>        <th class="col_heading level0 col3" >PAY_2</th>        <th class="col_heading level0 col4" >PAY_3</th>        <th class="col_heading level0 col5" >PAY_4</th>        <th class="col_heading level0 col6" >PAY_5</th>        <th class="col_heading level0 col7" >PAY_6</th>        <th class="col_heading level0 col8" >BILL_AMT1</th>        <th class="col_heading level0 col9" >BILL_AMT2</th>        <th class="col_heading level0 col10" >BILL_AMT3</th>        <th class="col_heading level0 col11" >BILL_AMT4</th>        <th class="col_heading level0 col12" >BILL_AMT5</th>        <th class="col_heading level0 col13" >BILL_AMT6</th>        <th class="col_heading level0 col14" >PAY_AMT1</th>        <th class="col_heading level0 col15" >PAY_AMT2</th>        <th class="col_heading level0 col16" >PAY_AMT3</th>        <th class="col_heading level0 col17" >PAY_AMT4</th>        <th class="col_heading level0 col18" >PAY_AMT5</th>        <th class="col_heading level0 col19" >PAY_AMT6</th>        <th class="col_heading level0 col20" >DEFAULT_NUM</th>    </tr>    <tr>        <th class="index_name level0" >DEFAULT</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7594a834_18d9_11ea_8c96_005056974139level0_row0" class="row_heading level0 row0" >No</th>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col0" class="data row0 col0" >177897</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col1" class="data row0 col1" >35.3831</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col2" class="data row0 col2" >0.194047</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col3" class="data row0 col3" >0.177726</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col4" class="data row0 col4" >0.182448</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col5" class="data row0 col5" >0.148781</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col6" class="data row0 col6" >0.121324</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col7" class="data row0 col7" >0.133333</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col8" class="data row0 col8" >51802.6</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col9" class="data row0 col9" >49536.3</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col10" class="data row0 col10" >47479.9</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col11" class="data row0 col11" >43373.7</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col12" class="data row0 col12" >40457.7</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col13" class="data row0 col13" >38876.3</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col14" class="data row0 col14" >6271.78</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col15" class="data row0 col15" >6690.66</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col16" class="data row0 col16" >5676.3</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col17" class="data row0 col17" >5393.51</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col18" class="data row0 col18" >5165.3</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col19" class="data row0 col19" >5750.73</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row0_col20" class="data row0 col20" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7594a834_18d9_11ea_8c96_005056974139level0_row1" class="row_heading level0 row1" >Yes</th>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col0" class="data row1 col0" >131170</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col1" class="data row1 col1" >35.7917</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col2" class="data row1 col2" >0.928015</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col3" class="data row1 col3" >0.81505</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col4" class="data row1 col4" >0.725113</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col5" class="data row1 col5" >0.640798</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col6" class="data row1 col6" >0.574615</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col7" class="data row1 col7" >0.553762</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col8" class="data row1 col8" >48815.4</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col9" class="data row1 col9" >47527.3</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col10" class="data row1 col10" >45397.9</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col11" class="data row1 col11" >42366.6</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col12" class="data row1 col12" >39774.2</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col13" class="data row1 col13" >38508.3</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col14" class="data row1 col14" >3390.38</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col15" class="data row1 col15" >3413.87</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col16" class="data row1 col16" >3479.44</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col17" class="data row1 col17" >3121.85</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col18" class="data row1 col18" >3299.47</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col19" class="data row1 col19" >3477.21</td>
#                         <td id="T_7594a834_18d9_11ea_8c96_005056974139row1_col20" class="data row1 col20" >1</td>
#             </tr>
#     </tbody></table>

# %%
plt.rcParams['figure.figsize'] = [13.0, 13.0]
# Correlation plot for Numerical variables
ax = sns.heatmap(
    traindf.corr(), 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
    linewidths=0.5 , cbar_kws={"shrink": 0.5}
)

ax.set_title("Correlation Plot",size= 14)

ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
plt.show()

# %%
NoDefault = traindf[traindf['DEFAULT_NUM'] == 0]["LIMIT_BAL"]
Default = traindf[traindf['DEFAULT_NUM'] == 1]["LIMIT_BAL"]
plt.rcParams['figure.figsize'] = [14,8]
plt.title('Distribution: Limit Balance with relation to Default', size=14)
sns.distplot(NoDefault,kde=True,bins=50, color="blue", kde_kws={"label": "Default = False"}, hist=False)
sns.distplot(Default,kde=True,bins=50, color="red",kde_kws={"label": "Default = True"})
plt.show()

# %% [markdown]
# ### Preprocessing for modelling

# %% [markdown]
# #### One Hot Encoding
# Machine learning algorithms cannot work with categorical variables directly; the one hot encoding method was employed to convert categorical data to a binary attribute for each category.

# %%
# Create dummy varibles from the categorical observations
catlist = ['SEX', 'EDUCATION', 'MARRIAGE']
dummylist = catlist
traindf_prepared = pd.get_dummies(data=traindf, columns=dummylist)

# %% [markdown]
# #### Scaling

# %%
scalelist = ['LIMIT_BAL', 'AGE','BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
newcols = list([x+'_scaled' for x in scalelist])
scaler = MinMaxScaler()
traindf_prepared[newcols] = pd.DataFrame(scaler.fit_transform(traindf_prepared[scalelist]),columns=newcols)

# %%
# Independent columns
X = traindf_prepared.drop(scalelist, axis=1) # Drop the prescaled columns
X = X.drop(['DEFAULT', 'DEFAULT_NUM'], axis=1) # Drop the target variables

# Target column
y = traindf_prepared['DEFAULT_NUM'].astype(int)

# Split Data into training and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = randomstate)
print("Training Shape: X =", X_train.shape, "y =", y_train.shape)
print("Validation Shape: X =", X_test.shape, "y =",y_test.shape)
# Out:
# Training Shape: X = (17500, 30) y = (17500,)
# Validation Shape: X = (7500, 30) y = (7500,)

# %% [markdown]
# ## Modelling: Equal Misclassification Costs

# %% [markdown]
# ### Model 1: Decision Tree

# %%
dt = DecisionTreeClassifier(random_state = randomstate)
dt.fit(X_train,y_train)
dt_preds = dt.predict(X_test)
# confusion matrix
dt_cm = pd.DataFrame(confusion_matrix(y_test, dt_preds), columns=np.unique(y_test), index = np.unique(y_test))
dt_cm.index.name = 'Actual'
dt_cm.columns.name = 'Predicted'

# %%
# plot feature importance
plt.rcParams['figure.figsize'] = [14,4]
feature_importances = pd.Series(dt.feature_importances_, index=X_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title("Decision Tree: Feature Importance", size="14")
plt.show()

# %%
# Show Confusion Matric and Accuracy
display(dt_cm.style.set_table_styles(dfstyles).\
        set_caption('Decision Tree: Confusion Matrix'))
print(classification_report(y_test, dt_preds))
# Out:
# <style  type="text/css" >
#     #T_77258e50_18d9_11ea_b62c_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_77258e50_18d9_11ea_b62c_005056974139" ><caption>Decision Tree: Confusion Matrix</caption><thead>    <tr>        <th class="index_name level0" >Predicted</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >Actual</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_77258e50_18d9_11ea_b62c_005056974139level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_77258e50_18d9_11ea_b62c_005056974139row0_col0" class="data row0 col0" >4746</td>
#                         <td id="T_77258e50_18d9_11ea_b62c_005056974139row0_col1" class="data row0 col1" >1104</td>
#             </tr>
#             <tr>
#                         <th id="T_77258e50_18d9_11ea_b62c_005056974139level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_77258e50_18d9_11ea_b62c_005056974139row1_col0" class="data row1 col0" >992</td>
#                         <td id="T_77258e50_18d9_11ea_b62c_005056974139row1_col1" class="data row1 col1" >658</td>
#             </tr>
#     </tbody></table>
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      5850
#            1       0.37      0.40      0.39      1650
#
#     accuracy                           0.72      7500
#    macro avg       0.60      0.61      0.60      7500
# weighted avg       0.73      0.72      0.72      7500

# %% [markdown]
# ### Model 1: Decision Tree - Tuning

# %% [markdown]
# #### Hyperparameters
# * max_depth (default=None): The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
# * max_features (default=auto): The number of features to consider when looking for the best split.
# * min_samples_leaf (default=1): The minimum number of samples required to be at a leaf node. A split point at any depth will only be considered if it leaves at least min_samples_leaf training samples in each of the left and right branches. This may have the effect of smoothing the model, especially in regression.
# * min_samples_split (default=2): The minimum number of samples required to split an internal node.

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'max_depth': [3, 5, 10, 20, 30, 50, 70, 100, 140],
    'max_features': [None, "auto", 2, 3, 4],
    'min_samples_leaf': [1, 2, 3, 4, 5],
    'min_samples_split': [2, 4, 8, 10, 12]
}

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = dt, param_grid = param_grid, 
                          cv = 3, n_jobs =-1)
# Fit the model against the grid of hyperparams
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort=False, random_state=4325,
#                                               splitter='best'),
#              iid='warn', n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 10, 20, 30, 50, 70, 100, 140],
#                          'max_features': [None, 'auto', 2, 3, 4],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_samples_split': [2, 4, 8, 10, 12]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(grid_search.best_params_)
# Out:
# {'max_depth': 3, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}

# %%
dt_best_model = grid_search.best_estimator_
bdt_preds = dt_best_model.predict(X_test)
# confusion matrix
bdt_cm = pd.DataFrame(confusion_matrix(y_test, bdt_preds), columns=np.unique(y_test), index = np.unique(y_test))
bdt_cm.index.name = 'Actual'
bdt_cm.columns.name = 'Predicted'
# Show Confusion Matrix and Accuracy
display(bdt_cm.style.set_table_styles(dfstyles).\
        set_caption('Tuned Decision Tree: Confusion Matrix'))
print(classification_report(y_test, bdt_preds))
# Out:
# <style  type="text/css" >
#     #T_9fedaafa_18d9_11ea_b7db_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_9fedaafa_18d9_11ea_b7db_005056974139" ><caption>Tuned Decision Tree: Confusion Matrix</caption><thead>    <tr>        <th class="index_name level0" >Predicted</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >Actual</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9fedaafa_18d9_11ea_b7db_005056974139level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9fedaafa_18d9_11ea_b7db_005056974139row0_col0" class="data row0 col0" >5569</td>
#                         <td id="T_9fedaafa_18d9_11ea_b7db_005056974139row0_col1" class="data row0 col1" >281</td>
#             </tr>
#             <tr>
#                         <th id="T_9fedaafa_18d9_11ea_b7db_005056974139level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9fedaafa_18d9_11ea_b7db_005056974139row1_col0" class="data row1 col0" >1064</td>
#                         <td id="T_9fedaafa_18d9_11ea_b7db_005056974139row1_col1" class="data row1 col1" >586</td>
#             </tr>
#     </tbody></table>
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      5850
#            1       0.68      0.36      0.47      1650
#
#     accuracy                           0.82      7500
#    macro avg       0.76      0.65      0.68      7500
# weighted avg       0.80      0.82      0.80      7500

# %%
# Create the parameter grid based on the results of random search 
param_grid = {'max_depth': [3, 5, 10, 20, 30, 50, 70, 100, 140], 'max_features': [None], 'min_samples_leaf': [1], 'min_samples_split': [2]}

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = dt, param_grid = param_grid, 
                          cv = 3, n_jobs =-1)
# Fit the model against the grid of hyperparams
grid_search.fit(X_train,y_train)

a.plot_grid_results(grid_search, param='max_depth', name = 'Max Tree Depth')

# %% [markdown]
# ### Model 2: Random Forest

# %%
rf = RandomForestClassifier(random_state = randomstate)
rf.fit(X_train,y_train)
rf_preds = rf.predict(X_test)
# confusion matrix
rf_cm = pd.DataFrame(confusion_matrix(y_test, rf_preds), columns=np.unique(y_test), index = np.unique(y_test))
rf_cm.index.name = 'Actual'
rf_cm.columns.name = 'Predicted'
# Out:
# C:\Users\durandt\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# plot feature importance
plt.rcParams['figure.figsize'] = [14,4]
feature_importances = pd.Series(rf.feature_importances_, index=X_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title("Random Forest: Feature Importance", size="14")
plt.show()

# %%
# Show Confusion Matric and Accuracy
display(rf_cm.style.set_table_styles(dfstyles).\
        set_caption('Random Forest: Confusion Matrix'))
print(classification_report(y_test, rf_preds))
# Out:
# <style  type="text/css" >
#     #T_a22852fe_18d9_11ea_bce1_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_a22852fe_18d9_11ea_bce1_005056974139" ><caption>Random Forest: Confusion Matrix</caption><thead>    <tr>        <th class="index_name level0" >Predicted</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >Actual</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a22852fe_18d9_11ea_bce1_005056974139level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a22852fe_18d9_11ea_bce1_005056974139row0_col0" class="data row0 col0" >5531</td>
#                         <td id="T_a22852fe_18d9_11ea_bce1_005056974139row0_col1" class="data row0 col1" >319</td>
#             </tr>
#             <tr>
#                         <th id="T_a22852fe_18d9_11ea_bce1_005056974139level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a22852fe_18d9_11ea_bce1_005056974139row1_col0" class="data row1 col0" >1145</td>
#                         <td id="T_a22852fe_18d9_11ea_bce1_005056974139row1_col1" class="data row1 col1" >505</td>
#             </tr>
#     </tbody></table>
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88      5850
#            1       0.61      0.31      0.41      1650
#
#     accuracy                           0.80      7500
#    macro avg       0.72      0.63      0.65      7500
# weighted avg       0.78      0.80      0.78      7500

# %% [markdown]
# ### Model 2: Random Forest - Tuning

# %% [markdown]
# #### Hyperparameters
# * bootstrap (default=True): Whether bootstrap samples are used when building trees. If False, the whole datset is used to build each tree.
# * max_depth (default=None): The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
# * max_features (default=auto): The number of features to consider when looking for the best split.
# * min_samples_leaf (default=1): The minimum number of samples required to be at a leaf node. A split point at any depth will only be considered if it leaves at least min_samples_leaf training samples in each of the left and right branches. This may have the effect of smoothing the model, especially in regression.
# * min_samples_split (default=2): The minimum number of samples required to split an internal node.
# * n_estimators (default=100) = The number of trees in the forest.

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'max_depth': [5, 10, 15],
    'max_features': ["auto", 2, 4],
    'min_samples_leaf': [1, 2, 3, 5],
    'min_samples_split': [2, 4],
    'n_estimators': [80, 90, 100]
}

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs =-1)
# Fit the model against the grid of hyperparams
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=10, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=4325, verbose=0,
#                                               warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15],
#                          'max_features': ['auto', 2, 4],
#                          'min_samples_leaf': [1, 2, 3, 5],
#                          'min_samples_split': [2, 4],
#                          'n_estimators': [80, 90, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(grid_search.best_params_)
# Out:
# {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 90}

# %%
rf_best_model = grid_search.best_estimator_
brf_preds = rf_best_model.predict(X_test)
# confusion matrix
brf_cm = pd.DataFrame(confusion_matrix(y_test, brf_preds), columns=np.unique(y_test), index = np.unique(y_test))
brf_cm.index.name = 'Actual'
brf_cm.columns.name = 'Predicted'
# Show Confusion Matrix and Accuracy
display(bdt_cm.style.set_table_styles(dfstyles).\
        set_caption('Tuned Random Forest: Confusion Matrix'))
print(classification_report(y_test, brf_preds))
# Out:
# <style  type="text/css" >
#     #T_f3420928_18d9_11ea_851e_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_f3420928_18d9_11ea_851e_005056974139" ><caption>Tuned Random Forest: Confusion Matrix</caption><thead>    <tr>        <th class="index_name level0" >Predicted</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >Actual</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f3420928_18d9_11ea_851e_005056974139level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f3420928_18d9_11ea_851e_005056974139row0_col0" class="data row0 col0" >5569</td>
#                         <td id="T_f3420928_18d9_11ea_851e_005056974139row0_col1" class="data row0 col1" >281</td>
#             </tr>
#             <tr>
#                         <th id="T_f3420928_18d9_11ea_851e_005056974139level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f3420928_18d9_11ea_851e_005056974139row1_col0" class="data row1 col0" >1064</td>
#                         <td id="T_f3420928_18d9_11ea_851e_005056974139row1_col1" class="data row1 col1" >586</td>
#             </tr>
#     </tbody></table>
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.89      5850
#            1       0.69      0.34      0.46      1650
#
#     accuracy                           0.82      7500
#    macro avg       0.76      0.65      0.68      7500
# weighted avg       0.81      0.82      0.80      7500

# %%
metrics.plot_confusion_matrix(rf_best_model, y_test, brf_preds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-18c81ca8197c> in <module>
# ----> 1 metrics.plot_confusion_matrix(rf_best_model, y_test, brf_preds)
#
# NameError: name 'metrics' is not defined

# %% [markdown]
# ### Model 3: K Nearest Neighbors

# %%
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
knn_preds = dt.predict(X_test)
# confusion matrix
knn_cm = pd.DataFrame(confusion_matrix(y_test, knn_preds), columns=np.unique(y_test), index = np.unique(y_test))
knn_cm.index.name = 'Actual'
knn_cm.columns.name = 'Predicted'

# %%
# Show Confusion Matric and Accuracy
display(knn_cm.style.set_table_styles(dfstyles).\
        set_caption('KNN: Confusion Matrix'))
print(classification_report(y_test, knn_preds))
# Out:
# <style  type="text/css" >
#     #T_f39e8fba_18d9_11ea_b1f7_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_f39e8fba_18d9_11ea_b1f7_005056974139" ><caption>KNN: Confusion Matrix</caption><thead>    <tr>        <th class="index_name level0" >Predicted</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >Actual</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f39e8fba_18d9_11ea_b1f7_005056974139level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f39e8fba_18d9_11ea_b1f7_005056974139row0_col0" class="data row0 col0" >4746</td>
#                         <td id="T_f39e8fba_18d9_11ea_b1f7_005056974139row0_col1" class="data row0 col1" >1104</td>
#             </tr>
#             <tr>
#                         <th id="T_f39e8fba_18d9_11ea_b1f7_005056974139level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f39e8fba_18d9_11ea_b1f7_005056974139row1_col0" class="data row1 col0" >992</td>
#                         <td id="T_f39e8fba_18d9_11ea_b1f7_005056974139row1_col1" class="data row1 col1" >658</td>
#             </tr>
#     </tbody></table>
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82      5850
#            1       0.37      0.40      0.39      1650
#
#     accuracy                           0.72      7500
#    macro avg       0.60      0.61      0.60      7500
# weighted avg       0.73      0.72      0.72      7500

# %% [markdown]
# ### Model 3: K Nearest Neighbors - Tuning

# %% [markdown]
# #### Hyperparameters
# * n_neighbors (default=5): Number of neighbors to use by default for kneighbors queries.

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'n_neighbors': [3,5,7,9,11,13,15,17]
}

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = knn, param_grid = param_grid, 
                          cv = 3, n_jobs =-1)
# Fit the model against the grid of hyperparams
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='warn', n_jobs=-1,
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11, 13, 15, 17]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(grid_search.best_params_)
# Out:
# {'n_neighbors': 17}

# %%
knn_best_model = grid_search.best_estimator_
bknn_preds = dt_best_model.predict(X_test)
# confusion matrix
bknn_cm = pd.DataFrame(confusion_matrix(y_test, bknn_preds), columns=np.unique(y_test), index = np.unique(y_test))
bknn_cm.index.name = 'Actual'
bknn_cm.columns.name = 'Predicted'
# Show Confusion Matrix and Accuracy
display(bknn_cm.style.set_table_styles(dfstyles).\
        set_caption('Tuned KNN: Confusion Matrix'))
print(classification_report(y_test, bknn_preds))
# Out:
# <style  type="text/css" >
#     #T_fdacdd02_18d9_11ea_be04_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_fdacdd02_18d9_11ea_be04_005056974139" ><caption>Tuned KNN: Confusion Matrix</caption><thead>    <tr>        <th class="index_name level0" >Predicted</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >Actual</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fdacdd02_18d9_11ea_be04_005056974139level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fdacdd02_18d9_11ea_be04_005056974139row0_col0" class="data row0 col0" >5569</td>
#                         <td id="T_fdacdd02_18d9_11ea_be04_005056974139row0_col1" class="data row0 col1" >281</td>
#             </tr>
#             <tr>
#                         <th id="T_fdacdd02_18d9_11ea_be04_005056974139level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fdacdd02_18d9_11ea_be04_005056974139row1_col0" class="data row1 col0" >1064</td>
#                         <td id="T_fdacdd02_18d9_11ea_be04_005056974139row1_col1" class="data row1 col1" >586</td>
#             </tr>
#     </tbody></table>
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      5850
#            1       0.68      0.36      0.47      1650
#
#     accuracy                           0.82      7500
#    macro avg       0.76      0.65      0.68      7500
# weighted avg       0.80      0.82      0.80      7500

# %%
a.plot_grid_results(grid_search, param='n_neighbors', name = 'Nearest Neighbors')

# %% [markdown]
# ## Modelling: Cost sensative learning

# %% [markdown]
# ### Model 1: Decision Tree

# %%
csdt = DecisionTreeClassifier(class_weight=classweight, random_state = randomstate)
#model = RandomForestClassifier(class_weight=classweight)
csdt.fit(X_train,y_train)
preds = csdt.predict(X_test)
# confusion matrix
csdt_cm = pd.DataFrame(confusion_matrix(y_test, preds), columns=np.unique(y_test), index = np.unique(y_test))
csdt_cm.index.name = 'Actual'
csdt_cm.columns.name = 'Predicted'

# %%
# plot feature importance
feature_importances = pd.Series(csdt.feature_importances_, index=X_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title("Cost Sensative Decision Tree: Feature Importance", size="14")
plt.show()

# %%
display(csdt_cm.style.set_table_styles(dfstyles).\
        set_caption('Cost Sensative Decision Tree: Confusion Matrix'))
print(classification_report(y_test, preds))
# Out:
# <style  type="text/css" >
#     #T_febbe1b6_18d9_11ea_b2ce_005056974139 caption {
#           font-size: 120%;
#           color: black;
#           text-align: center;
#     }</style><table id="T_febbe1b6_18d9_11ea_b2ce_005056974139" ><caption>Cost Sensative Decision Tree: Confusion Matrix</caption><thead>    <tr>        <th class="index_name level0" >Predicted</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >Actual</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_febbe1b6_18d9_11ea_b2ce_005056974139level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_febbe1b6_18d9_11ea_b2ce_005056974139row0_col0" class="data row0 col0" >4861</td>
#                         <td id="T_febbe1b6_18d9_11ea_b2ce_005056974139row0_col1" class="data row0 col1" >989</td>
#             </tr>
#             <tr>
#                         <th id="T_febbe1b6_18d9_11ea_b2ce_005056974139level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_febbe1b6_18d9_11ea_b2ce_005056974139row1_col0" class="data row1 col0" >1046</td>
#                         <td id="T_febbe1b6_18d9_11ea_b2ce_005056974139row1_col1" class="data row1 col1" >604</td>
#             </tr>
#     </tbody></table>
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83      5850
#            1       0.38      0.37      0.37      1650
#
#     accuracy                           0.73      7500
#    macro avg       0.60      0.60      0.60      7500
# weighted avg       0.73      0.73      0.73      7500

# %% [markdown]
# ## Model Comparison

# %%
# ROC
fpr_bdt, tpr_bdt, thresholds_bdt = roc_curve(y_test, bdt_preds)
fpr_brf, tpr_brf, thresholds_brf = roc_curve(y_test, brf_preds)
plt.rcParams['figure.figsize'] = [10,10]
plt.plot(fpr_brf, tpr_brf,'r-',label = 'RF')
plt.plot(fpr_bdt,fpr_bdt,'b-', label= 'DT')
plt.plot([0,1],[0,1],'k-',label='random')
plt.plot([0,0,1,1],[0,1,1,1],'g-',label='perfect')
plt.legend()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
